# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.applications import DenseNet121,EfficientNetB6
# Out:
# 2024-03-18 21:08:06.559318: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 21:08:06.559426: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-18 21:08:06.695194: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
IMAGE_SIZE= 112
BATCH_SIZE= 32

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/melanoma-cancer-dataset/train",
    shuffle=True,
    seed=123,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE,
)
# Out:
# Found 11879 files belonging to 2 classes.

# %%
dataset.class_names
# Out:
# ['Benign', 'Malignant']

# %%
test_set = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/melanoma-cancer-dataset/test",
    shuffle=False,
    seed=123,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE,
)
# Out:
# Found 2000 files belonging to 2 classes.

# %%
test_set.class_names
# Out:
# ['Benign', 'Malignant']

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in dataset.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.axis("off")
        plt.title(test_set.class_names[label_batch[i]])

# %%
def train_val_split(dataset, train_split=0.8, valid_split=0.2, shuffle= True, shuffle_size=10000):
    ds_size=len(dataset)
    if shuffle:
        ds=dataset.shuffle(shuffle_size,seed=12)
    train_size=int(ds_size*train_split)
    valid_size=int(ds_size*valid_split)
    valid_ds= ds.skip(train_size).take(valid_size)
    train_ds=ds.take(train_size)
    return train_ds, valid_ds

# %%
train_ds, val_ds = train_val_split(dataset, train_split=0.8, valid_split=0.2, shuffle= True)

# %%
def count_class(dataset):
    contagem_classes = {}
    for imagens, rotulos in train_ds:
        for rotulo in rotulos.numpy():
            if rotulo in contagem_classes:
                contagem_classes[rotulo] += 1
            else:
                contagem_classes[rotulo] = 1

    for classe, contagem in contagem_classes.items():
        print(f"Class {classe}: {contagem} samples")

# %%
count_class(train_ds)
# Out:
# Class 0: 4979 samples
# Class 1: 4500 samples

# %%
import numpy as np

# %%
def classification_model(num_classes, input_shape):
    return tf.keras.Sequential([
            tf.keras.layers.Rescaling(1./255),
            tf.keras.layers.RandomFlip("horizontal_and_vertical"),
            tf.keras.layers.RandomRotation(0.3),
             tf.keras.applications.EfficientNetB7(input_shape= input_shape, include_top=False, weights='imagenet'),
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

# %%
model = classification_model(2, (112, 112, 3))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip (RandomFlip)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ ?                      │   0 (unbuilt) │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb7 (Functional)     │ ?                      │    64,097,687 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ ?                      │   0 (unbuilt) │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 64,097,687 (244.51 MB)
#  Trainable params: 63,786,960 (243.33 MB)
#  Non-trainable params: 310,727 (1.19 MB)

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_set=test_set.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=15,
    verbose=1,
    mode="min",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=0,
)

# %%
reduce = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=5,
    verbose=1,
    mode="auto",
    min_delta=0.00001,
    cooldown=0,
    min_lr=0.0,
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=50,
    callbacks=[early_stop, reduce]
)
# Out:
# Epoch 1/50
# 2024-03-18 21:10:58.107478: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1/efficientnetb7_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 297s 518ms/step - accuracy: 0.8164 - loss: 0.4417 - val_accuracy: 0.5215 - val_loss: 2.3903 - learning_rate: 0.0010
# Epoch 2/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.8852 - loss: 0.2705 - val_accuracy: 0.5891 - val_loss: 1.2917 - learning_rate: 0.0010
# Epoch 3/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.8985 - loss: 0.2423 - val_accuracy: 0.7855 - val_loss: 0.4681 - learning_rate: 0.0010
# Epoch 4/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.9043 - loss: 0.2353 - val_accuracy: 0.8902 - val_loss: 0.2690 - learning_rate: 0.0010
# Epoch 5/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.9112 - loss: 0.2105 - val_accuracy: 0.8961 - val_loss: 0.2441 - learning_rate: 0.0010
# Epoch 6/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9200 - loss: 0.1880 - val_accuracy: 0.8999 - val_loss: 0.2460 - learning_rate: 0.0010
# Epoch 7/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 462ms/step - accuracy: 0.9202 - loss: 0.1884 - val_accuracy: 0.9113 - val_loss: 0.2115 - learning_rate: 0.0010
# Epoch 8/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 136s 459ms/step - accuracy: 0.9280 - loss: 0.1784 - val_accuracy: 0.8733 - val_loss: 0.2764 - learning_rate: 0.0010
# Epoch 9/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 136s 458ms/step - accuracy: 0.9336 - loss: 0.1701 - val_accuracy: 0.8653 - val_loss: 0.3614 - learning_rate: 0.0010
# Epoch 10/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 136s 457ms/step - accuracy: 0.9405 - loss: 0.1464 - val_accuracy: 0.9177 - val_loss: 0.2169 - learning_rate: 0.0010
# Epoch 11/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9407 - loss: 0.1541 - val_accuracy: 0.9341 - val_loss: 0.1698 - learning_rate: 0.0010
# Epoch 12/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 463ms/step - accuracy: 0.9386 - loss: 0.1492 - val_accuracy: 0.9164 - val_loss: 0.2265 - learning_rate: 0.0010
# Epoch 13/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 465ms/step - accuracy: 0.9380 - loss: 0.1568 - val_accuracy: 0.9383 - val_loss: 0.1776 - learning_rate: 0.0010
# Epoch 14/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 463ms/step - accuracy: 0.9502 - loss: 0.1222 - val_accuracy: 0.9409 - val_loss: 0.1647 - learning_rate: 0.0010
# Epoch 15/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9560 - loss: 0.1089 - val_accuracy: 0.9278 - val_loss: 0.2187 - learning_rate: 0.0010
# Epoch 16/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9549 - loss: 0.1204 - val_accuracy: 0.8864 - val_loss: 0.3282 - learning_rate: 0.0010
# Epoch 17/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 462ms/step - accuracy: 0.9532 - loss: 0.1094 - val_accuracy: 0.8991 - val_loss: 0.3001 - learning_rate: 0.0010
# Epoch 18/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 462ms/step - accuracy: 0.9601 - loss: 0.0990 - val_accuracy: 0.9472 - val_loss: 0.1529 - learning_rate: 0.0010
# Epoch 19/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9644 - loss: 0.0957 - val_accuracy: 0.9037 - val_loss: 0.3020 - learning_rate: 0.0010
# Epoch 20/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9695 - loss: 0.0823 - val_accuracy: 0.9257 - val_loss: 0.2180 - learning_rate: 0.0010
# Epoch 21/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 465ms/step - accuracy: 0.9667 - loss: 0.0862 - val_accuracy: 0.9274 - val_loss: 0.2081 - learning_rate: 0.0010
# Epoch 22/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 462ms/step - accuracy: 0.9687 - loss: 0.0793 - val_accuracy: 0.9324 - val_loss: 0.2184 - learning_rate: 0.0010
# Epoch 23/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9688 - loss: 0.0819
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 460ms/step - accuracy: 0.9688 - loss: 0.0819 - val_accuracy: 0.8742 - val_loss: 0.5338 - learning_rate: 0.0010
# Epoch 24/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 462ms/step - accuracy: 0.9804 - loss: 0.0500 - val_accuracy: 0.9611 - val_loss: 0.1416 - learning_rate: 1.0000e-04
# Epoch 25/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 463ms/step - accuracy: 0.9890 - loss: 0.0296 - val_accuracy: 0.9616 - val_loss: 0.1468 - learning_rate: 1.0000e-04
# Epoch 26/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.9929 - loss: 0.0192 - val_accuracy: 0.9599 - val_loss: 0.1696 - learning_rate: 1.0000e-04
# Epoch 27/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.9906 - loss: 0.0248 - val_accuracy: 0.9641 - val_loss: 0.1564 - learning_rate: 1.0000e-04
# Epoch 28/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 463ms/step - accuracy: 0.9927 - loss: 0.0166 - val_accuracy: 0.9637 - val_loss: 0.1758 - learning_rate: 1.0000e-04
# Epoch 29/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9945 - loss: 0.0134
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 463ms/step - accuracy: 0.9945 - loss: 0.0134 - val_accuracy: 0.9666 - val_loss: 0.1714 - learning_rate: 1.0000e-04
# Epoch 30/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 463ms/step - accuracy: 0.9959 - loss: 0.0126 - val_accuracy: 0.9641 - val_loss: 0.1766 - learning_rate: 1.0000e-05
# Epoch 31/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.9958 - loss: 0.0156 - val_accuracy: 0.9649 - val_loss: 0.1796 - learning_rate: 1.0000e-05
# Epoch 32/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.9654 - val_loss: 0.1877 - learning_rate: 1.0000e-05
# Epoch 33/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 464ms/step - accuracy: 0.9969 - loss: 0.0103 - val_accuracy: 0.9654 - val_loss: 0.1892 - learning_rate: 1.0000e-05
# Epoch 34/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9979 - loss: 0.0069
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 138s 465ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9662 - val_loss: 0.1895 - learning_rate: 1.0000e-05
# Epoch 35/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9976 - loss: 0.0114 - val_accuracy: 0.9649 - val_loss: 0.1914 - learning_rate: 1.0000e-06
# Epoch 36/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9967 - loss: 0.0101 - val_accuracy: 0.9649 - val_loss: 0.1902 - learning_rate: 1.0000e-06
# Epoch 37/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 461ms/step - accuracy: 0.9968 - loss: 0.0071 - val_accuracy: 0.9649 - val_loss: 0.1925 - learning_rate: 1.0000e-06
# Epoch 38/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 137s 460ms/step - accuracy: 0.9973 - loss: 0.0075 - val_accuracy: 0.9645 - val_loss: 0.1930 - learning_rate: 1.0000e-06
# Epoch 39/50
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9984 - loss: 0.0064
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 136s 457ms/step - accuracy: 0.9984 - loss: 0.0064 - val_accuracy: 0.9649 - val_loss: 0.1950 - learning_rate: 1.0000e-06
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'],color='red',label='train_loss')
plt.plot(history.history['val_loss'],color='blue',label='validation_loss')
plt.legend()
plt.show()

# %%
scores=model.evaluate(test_set)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.9249 - loss: 0.2326

# %%
class_names = ['Benign', 'Malignant']

# %%
import numpy as np
for images_batch, labels_batch in test_set.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Malignant
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# predicted label: Malignant

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence
