# %%
# !pip install Unidecode
# Out:
# Collecting Unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 14.0 MB/s eta 0:00:00
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.3.8

# %%
import torch
import torch.nn as nn
import string
import random
import sys
import unidecode

# %%
# !wget https://raw.githubusercontent.com/aladdinpersson/Machine-Learning-Collection/master/ML/Projects/text_generation_babynames/data/names.txt
# Out:
# --2024-04-09 00:32:59--  https://raw.githubusercontent.com/aladdinpersson/Machine-Learning-Collection/master/ML/Projects/text_generation_babynames/data/names.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7303572 (7.0M) [text/plain]
# Saving to: 'names.txt'
#
# names.txt           100%[===================>]   6.96M  --.-KB/s    in 0.03s
#
# 2024-04-09 00:32:59 (270 MB/s) - 'names.txt' saved [7303572/7303572]

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
all_characters = string.printable
n_characters = len(all_characters)

# %%
print(all_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print(n_characters)
# Out:
# 100

# %%
file = unidecode.unidecode(open('/kaggle/working/names.txt').read())

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embed = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden, cell):
        out = self.embed(x)
        out, (hidden ,cell) = self.lstm(out.unsqueeze(1), (hidden, cell))
        out = self.fc(out.reshape(out.shape[0], -1))
        return out, (hidden, cell)
    
    def init_hidden(self, batch_size):
        hidden = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        cell = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        return hidden, cell
    
class Generator():
    def __init__(self):
        self.chunk_len = 250
        self.num_epochs = 5000
        self.batch_size = 128
        self.print_every = 50
        self.hidden_size = 256
        self.num_layers = 2
        self.lr = 0.003
        
    def char_tensor(self, string):
        tensor = torch.zeros(len(string)).long()
        for c in range(len(string)):
            tensor[c] = all_characters.index(string[c])
        return tensor
            
    def get_random_batch(self):
        start_idx = random.randint(0, len(file) - self.chunk_len)
        end_idx = start_idx + self.chunk_len + 1
        text_str = file[start_idx:end_idx]
        text_input = torch.zeros(self.batch_size, self.chunk_len)
        text_target = torch.zeros(self.batch_size, self.chunk_len)
        
        for i in range(self.batch_size):
            start_idx = random.randint(0, len(file) - self.chunk_len)
            end_idx = start_idx + self.chunk_len + 1
            text_str = file[start_idx:end_idx]
            text_input[i,:] = self.char_tensor(text_str[:-1])
            text_target[i,:] = self.char_tensor(text_str[1:])
        
        return text_input.long(), text_target.long()
    
    def generate(self, initial_str= 'I', prediction_len=100, temperature=0.85):
        hidden, cell = self.rnn.init_hidden(batch_size=1)
        initial_input = self.char_tensor(initial_str)
        predicted = initial_str
        
        for p in range(len(initial_str) - 1):
            _, (hidden, cell) = self.rnn(initial_input[p].view(1), hidden, cell)
        
        last_char = initial_input[-1]
        for p in range(prediction_len):
            last_char = last_char.to(device)
            output, (hidden, cell) = self.rnn(last_char.view(1), hidden, cell)
            output_dist = output.data.view(-1).div(temperature).exp()
            top_char = torch.multinomial(output_dist, 1)[0]
            predicted_char = all_characters[top_char]
            predicted += predicted_char
            last_char = self.char_tensor(predicted_char)
            
        return predicted
        
    def train(self):
        #input_size, hidden_size, num_layers, output_size
        self.rnn = RNN(n_characters, self.hidden_size, self.num_layers, n_characters).to(device)
        optimizer = torch.optim.Adam(self.rnn.parameters(), lr=self.lr)
        criterion = nn.CrossEntropyLoss()
        print('=== Starting training === ')
        for epoch in range(1, self.num_epochs + 1):
            inp, target = self.get_random_batch()
            hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)
            
            self.rnn.zero_grad()
            loss = 0
            inp = inp.to(device)
            target = target.to(device)
            
            for c in range(self.chunk_len):
                output, (hidden, cell) = self.rnn(inp[:, c], hidden, cell)
                loss += criterion(output, target[:, c])
            
            loss.backward()
            optimizer.step()
            loss = loss.item() / self.chunk_len
            
            if epoch % self.print_every == 0:
                print(epoch)
                print(f'loss: {loss}')
                print(self.generate())

# %%
gennames = Generator()
gennames.train()
# Out:
# === Starting training ===
# 50
# loss: 2.190916259765625
# I*cig
# Saryn
# Soann
# Sotrama
# Shaniels
# Seath
# Rilenn
# Aliid
# Delline
# webla
# Davedin
# Corlie
# Kacia
# Mima
# Kelans
#
# 100
# loss: 1.929939208984375
# Irid
# Tomi
# Jaane
# Dean
# Wyne
# Frannald
# Cherie
# Benmany
# Daisal
# Alga
# Mailey
# Emere
# Jake
# Stangela
# Karick
# Anna
#
# 150
# loss: 1.7415177001953126
# I
# Perry
# Willa
# Amith
# Esris
# Nichanda
# Beth
# Hemeren
# Sanna
# Cadelyn
# Husto
# Robby
# Elizah
# Keline
# Coley
# Loure
# A
# 200
# loss: 1.5782607421875
# IRonda
# Lucie
# Julissa
# Cadery
# Aodor
# Melissac
# Carles
# Alessellie
# Ayanne
# Shayla
# Kyley
# Gerald
# Erye
# Natalya
#
# 250
# loss: 1.470765380859375
# Is
# Kelly
# Kennany
# Karian
# Carlece
# Leslie
# Arsus
# Karene
# Lil
# Dawn
# Ellion
# Joelynn
# Kassie
# Kyla
# Kalyssen
# Jay
#
# 300
# loss: 1.3069591064453125
# Ifade
# Kate
# Leigh
# Bennie
# Rochary
# Kimberly
# Martice
# Mariana
# Randa
# Rosalinne
# Mariana
# Madison
# Mady
# Rodney
#
# 350
# loss: 1.2359420166015624
# Ilva
# herece
# Raj
# Zenna
# Tia
# Tina
# Bonnie
# Calim
# Cory
# Claile
# Charleen
# Dariell
# Eliza
# Eleanor
# Elisabeth
# Ila
#
# 400
# loss: 1.217677490234375
# Ilberto
# Earneste
# Ernestine
# Hanna
# Jeanne
# Javiela
# Jayden
# Jonatane
# Marcella
# Margaret
# Maurice
# Mariela
# Mac
# 450
# loss: 1.21133056640625
# Iva
# Elena
# Elizabeth
# Emma
# Ethel
# Grail
# Grace
# Ina
# Imani
# Kevina
# Isabel
# Irda
# Jenny
# Harold
# Halle
# Ila
# Jasmin
# 500
# loss: 1.136780517578125
# Ivan
# Dale
# Edna
# Erleon
# Forrest
# Frances
# Gale
# Georgio
# Joseph
# Jess
# Jaylen
# Jerry
# Jessie
# Joas
# Julio
# Johnnie
# 550
# loss: 1.1013656005859376
# Iva
# Jacqueline
# Jaylen
# Jasiah
# Jayda
# Johnalyn
# Jazmine
# Jeania
# Joniah
# Justine
# Karina
# Karvin
# Kara
# Kelli
# Kr
# 600
# loss: 1.125576416015625
# Irid
# Earlie
# Dellan
# Frederick
# Frankie
# Glen
# Gioldan
# James
# Jayph
# Josephia
# Josef
# Joseb
# Julio
# Joseon
# Joshu
# 650
# loss: 1.0644757080078124
# I9a
# Nathania
# Natah
# Natashia
# Noel
# Nadine
# Nikia
# Nikia
# Nedra
# Nicolle
# Portia
# Renee
# Rocio
# Rosalinda
# Sal
# To
# 700
# loss: 1.0720836181640625
# Inda
# Jack
# Jamar
# Jess
# Joy
# Jerry
# Jeromas
# Jesus
# Joel
# Karl
# Lamar
# Lafare
# Maxwell
# Myron
# Milton
# Mike
# Morgan
#
# 750
# loss: 1.0397125244140626
# Isac
# Mattie
# Malachi
# Osia
# Ramon
# Ribi
# Sadie
# Shanda
# Shana
# Shiloh
# Shanice
# Tabatha
# Tonia
# Adele
# Abbey
# Aleja
# 800
# loss: 1.044815673828125
# Ignacio
# Mariano
# Melvin
# Reymue
# Steven
# Tammy
# Trini
# Trevor
# Tristin
# Troy
# Ulbert
# Wade
# Willionskia
# Yvett
# Za
# 850
# loss: 1.0449842529296876
# Ira
# Jaydan
# Jessie
# Jonathan
# Jeziah
# Jessie
# Johnmie
# Karkee
# Keana
# Kenya
# Kerry
# Kristie
# Latisha
# Latonya
# Luz
# 900
# loss: 1.06181640625
# Isail
# Sandy
# Randall
# Sidney
# Bettyce
# Margaret
# Robert
# Verson
# Yvonne
# Danyell
# Jimmie
# Cindy
# Robin
# Tammie
# Ca
# 950
# loss: 1.0010425415039061
# Izarah
# Jacey
# James
# Jaedin
# Jarrett
# Jalyn
# Jaquelyn
# Jaylene
# Jadelynn
# Jenise
# Jonathan
# Kalia
# Kamille
# Karly
# 1000
# loss: 1.0017479858398437
# Itzy
# Lester
# Markis
# Miles
# Alfred
# Ernesto
# Larry
# Charlie
# Lawrence
# Reginald
# George
# Jeff
# Kenneth
# Ryco
# Rona
# 1050
# loss: 1.0071639404296875
# Ixanca
# Evie
# Esther
# Evangelina
# Emma
# Genevieve
# Janice
# Jeanna
# Jewel
# Katty
# Katharine
# Lauren
# Laurel
# Lori
# E
# 1100
# loss: 1.0216585083007812
# Iveth
# Isis
# Jaylen
# Joelle
# Juastina
# Justine
# Julieann
# Karina
# Katie
# Kadanda
# Kali
# Karissa
# Kakee
# Kendra
# Kha
# 1150
# loss: 0.978125
# Isabela
# Lena
# Lizabeth
# Margaret
# Lynette
# Marie
# Marcy
# Mauri
# Merissa
# Mercedez
# Monique
# Melina
# Monica
# Paige
# 1200
# loss: 0.9764290161132813
# Isa
# Jacklyn
# Joy
# Kacla
# Kala
# Kisha
# Lanell
# Lana
# Lilli
# Lilliana
# Lilyanna
# Lilah
# Lindsay
# Linette
# Lisette
# Li
# 1250
# loss: 0.9799774780273437
# Inez
# Lora
# Mocey
# Ester
# Helen
# Olive
# Penny
# Alondra
# Flora
# Frankie
# Misti
# Terra
# Shelly
# Clara
# Latoria
# Cynthi
# 1300
# loss: 0.9594478759765624
# Isai
# Jamie
# Jasper
# Javier
# Jaydon
# Jamiel
# Jamie
# Jerald
# Jerry
# Johnie
# Joshio
# Joseph
# Julius
# Julveat
# Keandre
# 1350
# loss: 0.9788048706054687
# Irdence
# Hailey
# Hanna
# Janice
# Jessie
# Joy
# Kyla
# Lashonda
# Lindsay
# Lisandra
# Maribel
# Matilda
# Melony
# Missy
# No
# 1400
# loss: 0.9895877685546876
# Ines
# Lucille
# Luisa
# Macie
# Marlen
# Mariah
# Melisa
# Penelope
# Sabrena
# Scarlett
# Shelly
# Aidan
# Allysa
# Cristina
#
# 1450
# loss: 0.97009716796875
# Ime
# Erin
# Fayla
# Glenda
# Ginger
# Giovanna
# Guadalupe
# Halleigh
# Jamesia
# Janay
# Jannette
# Jeanne
# Jillian
# Julie
#
# 1500
# loss: 0.9778843383789062
# Irlene
# Joell
# Josue
# Kenney
# Kendra
# Lakendra
# Lorraine
# Madelyn
# Marian
# Myra
# Nickie
# Opal
# Olivia
# Rachelle
# Ra
# 1550
# loss: 0.9628394165039063
# Isack
# Jackie
# Jameson
# Jamari
# Jarrett
# Jared
# Jamel
# Jameson
# Jameriogo
# James
# Jamel
# Jamil
# Jameas
# Jaman
# Jaim
# 1600
# loss: 0.9339542846679687
# I[nada
# Isabell
# Jaiden
# Jahliza
# Jamila
# Janayah
# Jaelyn
# Janessa
# Jazmen
# Jenae
# Jissel
# Joyce
# Justice
# Juliann
# 1650
# loss: 0.95148193359375
# Ivan
# Jonathan
# Laurence
# Kendrick
# Leroy
# Ren
# Royal
# Rudolph
# Sebastian
# Simon
# Tomas
# Travis
# Alex
# Benito
# Brad
# 1700
# loss: 0.9325257568359375
# Isau
# Isaiah
# Isaiah
# Jadan
# Jacquelyn
# Jarret
# Jasen
# Jasper
# Jax
# Avery
# Casey
# Carolberto
# Callum
# Damon
# Darien
# 1750
# loss: 0.9404622802734375
# Isael
# Jan
# Johnnie
# Lee
# Mariano
# Myler
# Norman
# Nick
# Robby
# Rudolph
# Shannon
# Timothy
# Vance
# Walter
# Zachary
# Da
# 1800
# loss: 0.941799072265625
# Ilona
# Jan
# Janet
# Jerly
# June
# Luzr
# Marguuerite
# Nora
# Queen
# Subie
# Susanne
# Wendy
# William
# Alisa
# Annie
# Betsy
#
# 1850
# loss: 0.92893994140625
# Isabela
# Marie
# Sherry
# Alison
# Claudette
# Gabrielle
# Hope
# Leticia
# Madeline
# Margie
# Margie
# Carolyn
# Esther
# Te
# 1900
# loss: 0.9327433471679687
# Irby
# Carly
# Rose
# Ruby
# Yvette
# Maria
# Amy
# Catherine
# Sara
# Lillian
# Maria
# Wendy
# Marsha
# Lucy
# Lillian
# Lorraine
# 1950
# loss: 0.92622509765625
# Iren
# Kailey
# Kara
# Kaylei
# Kailyn
# Katelynn
# Keilah
# Kenzie
# Kerri
# Kendyl
# Keyli
# Kerry
# Kiya
# Kristal
# Kyndall
# L
# 2000
# loss: 0.91263232421875
# Isaiah
# Isiguel
# Israel
# Izaak
# Juan
# Lionel
# Lucien
# Lina
# Lucero
# Maximilian
# Michell
# Migun
# Mikkhit
# Mikenzo
# M
# 2050
# loss: 0.9226237182617187
# Irwie
# Inga
# Jefferson
# Julio
# Leonard
# Max
# Marquell
# Maxwell
# Mordis
# Oliver
# Randolph
# Raymond
# Terrell
# Billy
#
# 2100
# loss: 0.8982749633789062
# Isabel
# Jovita
# Kristie
# Leslie
# Marcela
# Michael
# Miriam
# Nina
# Rowena
# Teresita
# Ursula
# Velia
# Viola
# Alicia
# Am
# 2150
# loss: 0.9198924560546875
# Imelia
# Isabelle
# Jaclyn
# Janne
# Jennie
# Joey
# Katharine
# Katharine
# Kathrine
# Kellie
# Laurel
# Layla
# Lamona
# Lake
# 2200
# loss: 0.8996080322265625
# Irto
# Irvin
# Gregory
# Isaias
# Jalen
# Jamarcus
# Jaydon
# Jerald
# Jerrod
# Jeremy
# Jody
# Jordon
# Justus
# Luciano
# Mayra
# 2250
# loss: 0.9017622680664062
# IEll
# Ed
# Elan
# Emmett
# Erwin
# Esai
# Fabian
# Felton
# Francesco
# Francisco
# Francisco
# Geovany
# Giovanni
# Giovanni
#
# 2300
# loss: 0.9145493774414063
# Ivan
# Kenneth
# Kent
# Brock
# Darrell
# Darrell
# Frank
# Jake
# Jovan
# Roderick
# Skylar
# Tracy
# Walter
# Claude
# Ellis
# Ea
# 2350
# loss: 0.9271870727539062
# Ivon
# Patrick
# Randolph
# Wilson
# Norbert
# Johnnie
# Richard
# Joseph
# Rodney
# George
# Christopher
# Richard
# Gerald
#
# 2400
# loss: 0.9025198974609375
# Isiah
# Leo
# Lewis
# Mathias
# Mathew
# Nick
# Nick
# Shaine
# Ashton
# Colin
# Emerson
# Gilbert
# Greyson
# Gerald
# Gerald
# Ge
# 2450
# loss: 0.8862474365234375
# Ibra
# Janie
# Katha
# Kari
# Krista
# Lena
# Margo
# Marianne
# Marianne
# Marin
# Misia
# Nanci
# Nikki
# Tiana
# Adrienne
# Alis
# 2500
# loss: 0.9100108642578125
# Isabella
# Ivy
# Jackie
# Jaimee
# Jasmin
# Jasmin
# Jennefer
# Jessike
# Jewel
# Jocelynne
# Jo
# Joel
# Joycelyn
# Johnna
# Jod
# 2550
# loss: 0.8986737670898437
# Isael
# Jaymeen
# Jaylynn
# Jayden
# Jenelle
# Jenelle
# Jenessa
# Jenika
# Jesenia
# Jennette
# Josefa
# Jovanna
# June
# Just
# 2600
# loss: 0.8943324584960938
# Ira
# Anna
# Julia
# Maria
# Jacqueline
# Rebecca
# Debra
# Jacqueline
# Julia
# Jana
# Miranda
# Aimee
# Marie
# Laura
# Lela
# Pa
# 2650
# loss: 0.8935111083984375
# I
# Jerrik
# Alan
# Grover
# Bruce
# Carl
# Franklin
# Jeff
# Peter
# Louis
# Jay
# Jack
# Don
# Leonard
# Elmer
# Larry
# Reginald
# W
# 2700
# loss: 0.8966167602539062
# Isaac
# Ivan
# Robert
# Julian
# Daniel
# David
# Zachary
# Patrick
# Anthony
# William
# James
# Eduardo
# Matthew
# Joseph
# An
# 2750
# loss: 0.8725126342773437
# Iona
# Anye
# Antoinette
# Antonia
# Arlene
# Clarissa
# Corey
# Deborah
# Diana
# Emma
# Esther
# Harriet
# Hope
# Jeanne
# Jody
# 2800
# loss: 0.8806470947265626
# Isabella
# Jalisa
# Jocelyn
# Katy
# Kelsey
# Kristie
# Angela
# Sheila
# Britney
# Lindsay
# Rose
# Katrina
# Kayla
# Jocelyn
#
# 2850
# loss: 0.8899054565429687
# Inez
# Ellie
# Elsie
# Enriqueta
# Erma
# Faye
# Gay
# Harriett
# Jeanne
# Laurel
# Leann
# Lenore
# Letha
# Lora
# Malinda
# Mercy
# 2900
# loss: 0.8645020751953125
# Isabelle
# Mallory
# Marsha
# Anita
# Dianne
# Christine
# Joanna
# Alisa
# Heather
# Dorothy
# Kimberly
# Domingo
# Jennifer
# 2950
# loss: 0.8848907470703125
# Inez
# Ernestine
# Jacquelyn
# Janelle
# Janis
# Janell
# Joanna
# Jordan
# Karla
# Latonia
# Latricia
# Latonya
# Linette
# Li
# 3000
# loss: 0.87628759765625
# Irwin
# Gracie
# Ilia
# Janel
# Jenee
# Jennie
# Jessy
# Joelle
# Joe
# Johnni
# Johnisha
# Jourdan
# Jovi
# Julieanne
# Justina
#
# 3050
# loss: 0.878290771484375
# Isaac
# Jacobi
# Jasiel
# Jaydon
# Jean
# Jaylen
# Jean
# Jerrell
# Jovan
# Juancarlos
# Jordon
# Judah
# Kaee
# Kaiden
# Kalein
#
# 3100
# loss: 0.88454833984375
# Isabeth
# Eunice
# Evelyn
# Frances
# Isabel
# Jane
# Jeannette
# Jenny
# Joy
# Naomi
# Rene
# Rory
# Tracey
# Amelia
# Ariana
# Es
# 3150
# loss: 0.8785892333984375
# Inez
# Joanna
# Leah
# Lorena
# Marcia
# Margarite
# Marianne
# Maryjane
# Melissa
# Mistina
# Raquel
# Roseanna
# Shareka
# Sh
# 3200
# loss: 0.901050048828125
# Irene
# Rebecca
# Loretta
# Carola
# Evelyn
# Evelyn
# Vivian
# Sonia
# Rebecca
# Anna
# Cara
# Megan
# Regina
# Debra
# Alice
# Be
# 3250
# loss: 0.8694713134765625
# Isha
# Jasmine
# Karolyn
# Katharine
# Kerrie
# Lucia
# Malinda
# Marla
# Mercedes
# Nella
# Pattie
# Pearl
# Rena
# Ronda
# Sand
# 3300
# loss: 0.8791106567382813
# Imel
# Ivan
# If
# Isiah
# Jacques
# Jamar
# Jarod
# Jean
# Jeffery
# Jerald
# Jessiah
# Judah
# Junioger
# Kane
# Kenji
# Kendrick
# 3350
# loss: 0.8981580200195313
# Isabelle
# Jacque
# Janice
# Jessica
# Keila
# Kori
# Lorraine
# Monika
# Quiana
# Rachelle
# Rylinda
# Savanah
# Samiyah
# Val
# 3400
# loss: 0.8645592041015625
# Ilya
# India
# Irina
# Jaela
# Jamaiah
# Jaelene
# Jaida
# Jamie
# Jameka
# Janai
# Janae
# Janee
# Janey
# Jayne
# Jazlynn
# Jayli
# 3450
# loss: 0.8705078125
# Isaac
# Jacob
# Jan
# Jarrett
# Jeffry
# Jonathan
# Jordan
# Joseluis
# Julian
# Reginald
# Roy
# Tayden
# Warren
# Willie
# Jack
# 3500
# loss: 0.8735247802734375
# Issabela
# Jenifer
# Kellye
# Kenisha
# Kiri
# Kirsty
# Krissy
# Kristain
# Kristen
# Kristyn
# Kyndal
# Lainey
# Larissa
# Lay
# 3550
# loss: 0.8642122192382813
# Isabelle
# Kelsey
# Kerry
# Leila
# Lizette
# Lizeth
# Lorelei
# Loree
# Lorrie
# Lyssa
# Makinda
# Magdalena
# Makala
# Manuel
# 3600
# loss: 0.8663910522460937
# Isabelle
# Jazmyn
# Jesse
# Joy
# Julianna
# Karen
# Katelin
# Kayley
# Kyra
# Lexie
# Lianna
# Linsey
# Mara
# Leeann
# Macie
# Ma
# 3650
# loss: 0.8669573974609375
# Irvin
# Jackson
# Jerome
# Kirk
# Leonidas
# Max
# Ned
# Orwina
# Randolph
# Roger
# Rubin
# Sterling
# Thaddeus
# Tommie
# Valen
# 3700
# loss: 0.8617024536132812
# Isabeth
# Adela
# Alexandria
# Avelyn
# Averi
# Ayana
# Bridgett
# Britteny
# Britttney
# Brookelyn
# Brynlee
# Brynlee
# Cai
# 3750
# loss: 0.859742431640625
# Isabelle
# Annette
# Audra
# Claire
# Cindy
# Cora
# Helen
# Heidi
# Kelly
# Leslie
# Martha
# Adrienne
# Julie
# Lorraine
# Loui
# 3800
# loss: 0.8617953491210938
# Ira
# Isaurado
# Jett
# Karl
# Layne
# Leslie
# Lorenza
# Mary
# Mikayla
# Nola
# Rosana
# Rosio
# Shelli
# Shyanne
# Simone
# Stac
# 3850
# loss: 0.8451723022460937
# Irace
# Mila
# Nevaeh
# Nia
# Nikita
# Nina
# Paula
# Raylee
# Reece
# Rosalie
# Rosalie
# Sage
# Sabina
# Samaya
# Shayla
# Sherry
# 3900
# loss: 0.8505960693359375
# Isabell
# Jiselle
# Laytha
# Maheklani
# Amaya
# Amyra
# Annelise
# Arianna
# Fatima
# Hailee
# Jane
# Jazmine
# Maddison
# Ari
# 3950
# loss: 0.8488113403320312
# Isa
# Jackelyn
# Janet
# Jaymee
# Jazmin
# Jenna
# Jennyfer
# Jewell
# Jodi
# Johnnesha
# Johnny
# Jonna
# Jovana
# Jozlyn
# Jose
# 4000
# loss: 0.847693603515625
# Ila
# Holly
# Ivory
# Janelle
# Janine
# Juana
# Lora
# Lorene
# Loren
# Rosalie
# Rosie
# Ryan
# Roxann
# Suzanne
# Tricia
# Veron
# 4050
# loss: 0.8555227661132813
# Iva
# Jeanne
# Jonna
# Kimber
# Lorie
# Melanie
# Millie
# Mona
# Olga
# Regina
# Robyn
# Stella
# Tamara
# Yvonne
# Adriana
# Arle
# 4100
# loss: 0.8311234741210938
# Isaac
# Jason
# Jermaine
# Jonah
# Karl
# Keegan
# Kristopher
# Lance
# Kenneth
# Kristopher
# Larry
# Levi
# Rick
# Ronnie
# Ter
# 4150
# loss: 0.85879443359375
# Isac
# Itzae
# Izaiah
# Jairy
# Jagger
# Jarod
# Kaig
# Keegan
# Koby
# Lauren
# Leon
# Luc
# Ross
# Wesley
# Adrian
# Alberto
# Anto
# 4200
# loss: 0.8441506958007813
# Iliana
# Indigo
# Jade
# Jaylee
# Jayleen
# Jenae
# Journey
# Joli
# Josephina
# Kacy
# Kaliah
# Kameron
# Karolyn
# Karsyn
# Kay
# 4250
# loss: 0.8415208740234374
# Indi
# Iesha
# James
# Juliette
# Kassandra
# Kimberlie
# Leigh
# Lee
# Lela
# Leona
# Lola
# Margie
# Marlene
# Margie
# Marilee
# 4300
# loss: 0.8475692138671875
# Imel
# Iliana
# Inaya
# Jackelin
# Jacklin
# Jacinda
# Jaclynn
# Jacey
# Jamilah
# Jamesha
# Janina
# Janya
# Jaritza
# Jazmyne
# 4350
# loss: 0.8631468505859375
# Isabella
# Jaci
# Jasmyn
# Jasmyne
# Jazlynn
# Jesica
# Jocelynn
# Johana
# Joselyn
# Kaira
# Kaitlan
# Kambria
# Karlene
# Kar
# 4400
# loss: 0.8530350952148438
# Imani
# Julienne
# Kara
# Karina
# Kari
# Kate
# Kaycee
# Keiara
# Kimberley
# Kimiko
# Laniyah
# Lashaunda
# Leandra
# Leighan
# 4450
# loss: 0.8652993774414063
# Indiana
# Isabelle
# Jade
# Janiyah
# Jaylee
# Jaylee
# Jaylyn
# Jenavieve
# Jennah
# Jenelle
# Jezel
# Joseline
# Josephina
#
# 4500
# loss: 0.8508837890625
# Isaac
# Julia
# Mavis
# Dolly
# Freddie
# Natalie
# Bonnie
# Bertha
# Lena
# Lillian
# Patsy
# Virginia
# Carmen
# Edna
# Eunice
#
# 4550
# loss: 0.8429033813476563
# Isabela
# Irma
# Katharine
# Laurel
# Lila
# Marcella
# Margot
# Mariaelena
# Mariadejesus
# Marianne
# Maricruz
# Mariza
# M
# 4600
# loss: 0.8431524047851563
# Isekar
# Lamar
# Laurence
# Levi
# Linda
# Lisamarie
# Lorie
# Lynnette
# Madeleine
# Madelyn
# Maryana
# Marisela
# Mariadej
# 4650
# loss: 0.8639442749023437
# Ivan
# Jay
# Lee
# Martin
# Max
# Nathan
# Randall
# Eugene
# Kurt
# Lewis
# Alexander
# Victor
# Eugene
# Arnold
# Benjamin
# Enri
# 4700
# loss: 0.8397879638671875
# IJosefina
# Gracelyn
# Harold
# Emma
# Fannie
# Jacqueline
# Kristy
# Linda
# Selene
# Sophia
# Taylor
# Angel
# Annie
# Doris
#
# 4750
# loss: 0.8401395263671875
# Isabelle
# Brenna
# Deanna
# Annie
# Ashlee
# Ashley
# Caroline
# Claudia
# Jacquelyn
# Adriana
# Catherine
# Jennie
# Kathle
# 4800
# loss: 0.8370296630859375
# Iman
# Ashley
# Corbin
# Ezra
# Corey
# Noah
# Pablo
# Riley
# Scott
# Austin
# Brennan
# Cason
# Conrad
# Dominic
# Ernesto
# Hugh
# 4850
# loss: 0.8367863159179687
# Issac
# Martin
# Matthew
# Troy
# Alvin
# Dean
# Demetrius
# Jeff
# Jeff
# Walter
# Alex
# Clayton
# Danny
# Geoffrey
# Javier
# Je
# 4900
# loss: 0.8506614379882812
# Iceah
# Jaciel
# Jalil
# Jamel
# Janell
# Jaydon
# Jaylon
# Jaydin
# Jaydin
# Jermaine
# Job
# Judit
# Julien
# Kavi
# Khai
# Khang
# 4950
# loss: 0.8391233520507813
# Isabelle
# Josephine
# Lillian
# Yvonne
# Vivian
# Yolanda
# Charlotte
# Georgia
# Barbara
# Susan
# Kay
# Maria
# Naomi
# Delo
# 5000
# loss: 0.8264745483398438
# Imelda
# Eva
# Evie
# Flora
# Freida
# Georgia
# Gertrude
# Gwen
# Hilda
# Ida
# Iris
# Jacqueline
# Jennie
# Jessie
# Jody
# Judy
